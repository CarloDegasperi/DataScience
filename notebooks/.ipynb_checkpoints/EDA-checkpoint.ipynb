# %% [markdown]
# # Progetto finale - notebook 1

# %% [markdown]
# ## Organizzazione dataset

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../functions')

from IPython.display import Image, display

# %%
import numpy as np 
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

import json

from pathlib import Path
from shapely.geometry import Point
from shapely.geometry import shape

import functions as fs

# %%
data_path = Path('../data/raw')
APPA_path = Path('../data/external')

files = {'grid':'trentino-grid.geojson',
         'adm_reg':'administrative_regions_Trentino.json',
         'weather':'meteotrentino-weather-station-data.json',
         'precip':'precipitation-trentino.csv',
         'precip-avail':'precipitation-trentino-data-availability.csv',
         'SET-1':'SET-nov-2013.csv',
         'SET-2':'SET-dec-2013.csv',
         'SET-lines':'line.csv',
         'twitter':'social-pulse-trentino.geojson'}

APPA_files = {'data_pol':'APPA_extended.csv',
              'pos':'posizioni_stazioni_appa.csv'}

grid_df = gpd.read_file(data_path / files['grid'])

# %% [markdown]
# ### MeteoTrentino, ARPA

# %%
with open(data_path / files['weather']) as f:
    weather_json = json.load(f)

weather = gpd.GeoDataFrame(weather_json['features'])

weather = fs.fill_hole(weather)

weather_df = fs.winds_split(weather)

weather_df['geometry'] = weather_df['geomPoint.geom'].apply(lambda x:Point(x['coordinates'][0], x['coordinates'][1]))
weather_df.drop(columns=['geomPoint.geom'],inplace=True)

weather_df = fs.restructure_weather(weather_df)

weather_df.head()
# Out:
#   Stazione        Data  Ora  Temperature  Precipitation  Winds_spd  Winds_dir  \
# 0    T0071  2013-11-01    0          8.4            0.0        0.1      205.0
# 1    T0071  2013-11-01    1          8.2            0.0        0.5      231.0
# 2    T0071  2013-11-01    2          8.0            0.0        0.0      294.0
# 3    T0071  2013-11-01    3          7.8            0.0        0.5      273.0
# 4    T0071  2013-11-01    4          6.6            0.0        0.1      274.0
#
#                    geometry
# 0  POINT (10.79583 46.3134)
# 1  POINT (10.79583 46.3134)
# 2  POINT (10.79583 46.3134)
# 3  POINT (10.79583 46.3134)
# 4  POINT (10.79583 46.3134)

# %% [markdown]
# ### APPA

# %%
APPA_df = pd.read_csv(APPA_path / APPA_files['data_pol'], encoding='latin1')

APPA_df['Valore'] = pd.to_numeric(APPA_df['Valore'], errors='coerce')
APPA_df['Ora'] = pd.to_numeric(APPA_df['Ora'], errors='coerce')

# %%
APPA_pos = pd.read_csv(APPA_path / APPA_files['pos'])
APPA_pos[['lat', 'lon']] = APPA_pos['Posizione'].str.split(',', expand=True)
APPA_pos = APPA_pos.drop('Posizione', axis=1)

data_names = ['Piana Rotaliana', 'Riva del Garda', 'Monte Gaza', 'Parco S. Chiara', 'Rovereto', 'Via Bolzano','A22 (Avio)', 'Borgo Valsugana']

APPA_pos['data names'] = data_names

APPA_df['geometry'] = APPA_df['Stazione'].map(fs.get_geometry_APPA(APPA_df, APPA_pos))

APPA_df['Inquinante'] = APPA_df['Inquinante'].replace({'Biossido Zolfo': 'SO2', 'Biossido di Azoto': 'NO2', 'Ossido di Carbonio': 'CO', 'Ozono': 'O3'})

APPA_df.head()
# Out:
#           Stazione Inquinante        Data  Ora  Valore Unità di misura  \
# 0  Parco S. Chiara       PM10  2013-11-01    1    23.0           µg/mc
# 1  Parco S. Chiara       PM10  2013-11-01    2    25.0           µg/mc
# 2  Parco S. Chiara       PM10  2013-11-01    3    23.0           µg/mc
# 3  Parco S. Chiara       PM10  2013-11-01    4    21.0           µg/mc
# 4  Parco S. Chiara       PM10  2013-11-01    5    20.0           µg/mc
#
#                    geometry  EAQI
# 0  POINT (11.1262 46.06292)  None
# 1  POINT (11.1262 46.06292)  None
# 2  POINT (11.1262 46.06292)  None
# 3  POINT (11.1262 46.06292)  None
# 4  POINT (11.1262 46.06292)  None

# %%
APPA_df['Valore'] = pd.to_numeric(APPA_df['Valore'], errors='coerce')
APPA_comp_df = APPA_df.pivot_table(index=['Stazione', 'Data', 'Ora'],columns='Inquinante', values='Valore').reset_index()
#APPA_comp_df[APPA_comp_df.isna() ] = 0
APPA_comp_df['geometry'] = APPA_comp_df['Stazione'].map(fs.get_geometry_APPA(APPA_df, APPA_pos))
APPA_comp_df.head()
# Out:
# Inquinante    Stazione        Data  Ora    CO   NO2  O3  PM10  PM2.5  SO2  \
# 0           A22 (Avio)  2013-11-01    1  0.55  53.0 NaN  23.0    NaN  NaN
# 1           A22 (Avio)  2013-11-01    2  0.51  48.0 NaN  33.0    NaN  NaN
# 2           A22 (Avio)  2013-11-01    3  0.49  41.0 NaN  35.0    NaN  NaN
# 3           A22 (Avio)  2013-11-01    4  0.50  41.0 NaN  35.0    NaN  NaN
# 4           A22 (Avio)  2013-11-01    5  0.43  40.0 NaN  15.0    NaN  NaN
#
# Inquinante                   geometry
# 0           POINT (10.97043 45.74215)
# 1           POINT (10.97043 45.74215)
# 2           POINT (10.97043 45.74215)
# 3           POINT (10.97043 45.74215)
# 4           POINT (10.97043 45.74215)

# %%
# aggiungiamo una colonna per l'indice di qualità dell'aria
display(Image(filename='../images/TABELLA_APPA.png'))

# %%
APPA_comp_df = fs.add_eaqi(APPA_comp_df)
APPA_comp_df.head()
# Out:
# Inquinante    Stazione        Data  Ora    CO   NO2  O3  PM10  PM2.5  SO2  \
# 0           A22 (Avio)  2013-11-01    1  0.55  53.0 NaN  23.0    NaN  NaN
# 1           A22 (Avio)  2013-11-01    2  0.51  48.0 NaN  33.0    NaN  NaN
# 2           A22 (Avio)  2013-11-01    3  0.49  41.0 NaN  35.0    NaN  NaN
# 3           A22 (Avio)  2013-11-01    4  0.50  41.0 NaN  35.0    NaN  NaN
# 4           A22 (Avio)  2013-11-01    5  0.43  40.0 NaN  15.0    NaN  NaN
#
# Inquinante                   geometry  EAQI
# 0           POINT (10.97043 45.74215)  fair
# 1           POINT (10.97043 45.74215)  fair
# 2           POINT (10.97043 45.74215)  fair
# 3           POINT (10.97043 45.74215)  fair
# 4           POINT (10.97043 45.74215)  good

# %% [markdown]
# ### SET

# %%
SET_1_df         = pd.read_csv(data_path / files['SET-1'], header=None)
SET_2_df         = pd.read_csv(data_path / files['SET-2'], header=None)
SET_l_df         = pd.read_csv(data_path / files['SET-lines'])

SET_1_df.rename(columns={0: 'line_id', 1: 'time', 2: 'value'}, inplace=True)
SET_2_df.rename(columns={0: 'line_id', 1: 'time', 2: 'value'}, inplace=True)

# %%
SET_l_df
# Out:
#       SQUAREID    LINESET  NR_UBICAZIONI
# 0          155  DG1031221              4
# 1          272  DG1031221             72
# 2          273  DG1031221             21
# 3          276  DG1003117             34
# 4          277  DG1003117              3
# ...        ...        ...            ...
# 2570     10983  DG1013504              5
# 2571     10984  DG1013504              2
# 2572     11097  DG1013503              1
# 2573     11098  DG1013503              6
# 2574     11099  DG1013503              3
#
# [2575 rows x 3 columns]

# %%
# prima di tutto estraiamo il numero di utenze della rete elettrica per ciscuna linea e casella della griglia
users = SET_l_df.groupby("LINESET")["NR_UBICAZIONI"].sum().reset_index()                                              \
    .rename(columns={"NR_UBICAZIONI": "UBICAZIONI_PER_LINEA"})  \
    .set_index("LINESET")

# %%
# visto che sono feature utili, separiamo il tempo in giorno, orario e giorno della settimana, poi uniamo i due dataframe

# day va da 0 a 60
#weekday va da 0 (lunedi') a 6 (domenica)

# QUESTA CELLA E' DA SPOSTARE

SET_1_df = SET_time(SET_1_df)
SET_2_df = SET_time(SET_2_df)

SET_2_df['day'] += 30

SET_df = pd.concat([SET_1_df, SET_2_df], axis=0, ignore_index=True)

del SET_1_df
del SET_2_df

SET_df = SET_df[['line_id', 'day', 'time', 'weekday', 'value']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       1 # visto che sono feature utili, separiamo il tempo in giorno, orario e giorno della settimana, poi uniamo i due dataframe
#       2
#       3 # day va da 0 a 60
#       4 #weekday va da 0 (lunedi') a 6 (domenica)
#       5
#       6 # QUESTA CELLA E' DA SPOSTARE
# ----> 8 SET_1_df = SET_time(SET_1_df)
#       9 SET_2_df = SET_time(SET_2_df)
#      11 SET_2_df['day'] += 30
#
# NameError: name 'SET_time' is not defined

# %%
SET_df

# %% [markdown]
# ### Unione DataFrame

# %%
map = fs.station_map(weather_df, APPA_comp_df)
final_df = fs.combine_dfs(weather_df, APPA_comp_df, map)

final_df.head()
# Out:
#          Data  Ora Stazione appa              geometry appa Stazione meteo  \
# 0  2013-11-01    1    A22 (Avio)  POINT (10.97043 45.74215)          T0405
# 1  2013-11-01    2    A22 (Avio)  POINT (10.97043 45.74215)          T0405
# 2  2013-11-01    3    A22 (Avio)  POINT (10.97043 45.74215)          T0405
# 3  2013-11-01    4    A22 (Avio)  POINT (10.97043 45.74215)          T0405
# 4  2013-11-01    5    A22 (Avio)  POINT (10.97043 45.74215)          T0405
#
#               geometry meteo  SO2   NO2    CO  O3  PM10  PM2.5  EAQI  \
# 0  POINT (11.02374 45.78614)  NaN  53.0  0.55 NaN  23.0    NaN  fair
# 1  POINT (11.02374 45.78614)  NaN  48.0  0.51 NaN  33.0    NaN  fair
# 2  POINT (11.02374 45.78614)  NaN  41.0  0.49 NaN  35.0    NaN  fair
# 3  POINT (11.02374 45.78614)  NaN  41.0  0.50 NaN  35.0    NaN  fair
# 4  POINT (11.02374 45.78614)  NaN  40.0  0.43 NaN  15.0    NaN  good
#
#    Temperature  Precipitation  Winds_spd  Winds_dir
# 0         10.5            0.0        NaN        NaN
# 1         10.8            0.0        NaN        NaN
# 2         10.9            0.0        NaN        NaN
# 3         11.2            0.0        NaN        NaN
# 4         11.3            0.0        NaN        NaN

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Osserviamo l'andamento della temperatura in funzione dell'ora e del giorno:
daily_temp = (final_df.groupby(['Data'])['Temperature'].mean().reset_index())
hourly_temp = (final_df.groupby(['Ora'])['Temperature'].mean().reset_index())

plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
plt.plot(daily_temp['Data'], daily_temp['Temperature'])
plt.xlabel('Date')
plt.ylabel('Average Temperature')
plt.title('Average Daily Temperature')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(hourly_temp['Ora'], hourly_temp['Temperature'])
plt.xlabel('Hour')
plt.ylabel('Average Temperature')
plt.title('Average Hourly Temperature')
plt.grid(True)

plt.show()

# %% [markdown]
# Chiaramente la temperatura decresce passando da Novembre a Dicembre e dimostra un chiaro trend nel corso della giornata, con un minimo alle 7 di mattina e un massimo alle due del pomeriggio. Nessuno di questi comportamenti ci sorprende.

# %%
# Ci chiediamo se la velocità del vento segue un simile andamento
daily_wind = (final_df.groupby(['Data'])['Winds_spd'].mean().reset_index())
hourly_wind = (final_df.groupby(['Ora'])['Winds_spd'].mean().reset_index())

plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
plt.plot(daily_wind['Data'], daily_wind['Winds_spd'])
plt.xlabel('Date')
plt.ylabel('Average Wind Speed')
plt.title('Average Daily Wind Speed')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(hourly_wind['Ora'], hourly_wind['Winds_spd'])
plt.xlabel('Hour')
plt.ylabel('Average Wind Speed')
plt.title('Average Hourly Wind Speed')
plt.grid(True)

plt.show()

# %% [markdown]
# Non osserviamo un andamento chiaro nell'andamento della velocità del vento nel periodo studiato. Tuttavia appare chiaro che la velocità del vento è maggiore tra le 10 e le 16. Questo è imputabile al Sole che splende maggiormente in quell'orario, riscaldando l'atmosfera e di conseguenza aumentando l'energia cinetica delle molecole e incrementando le turbolenze.

# %%
# Verifichiamo se la concentrazione dei vari inquinanti esprime una dipendenza dall'orario (probabile) o dal giorno (possibile)
pols = ['SO2', 'NO2', 'CO', 'O3', 'PM10', 'PM2.5']

# NOTA: per la qualità dell'aria fare solo andamento orario e usare istogramma con 1 bin per ogni livello dell'EAQI 

for p in pols
# Out:
# Index(['Data', 'Ora', 'Stazione appa', 'geometry appa', 'Stazione meteo',
#        'geometry meteo', 'SO2', 'NO2', 'CO', 'O3', 'PM10', 'PM2.5', 'EAQI',
#        'Temperature', 'Precipitation', 'Winds_spd', 'Winds_dir'],
#       dtype='object')
